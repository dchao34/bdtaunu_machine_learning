# %%
# %matplotlib inline

# %%
import numpy as np
import iopro
import matplotlib.pyplot as plt
from custom_python_utilities.histR import histR, histRec

# %%
X = iopro.genfromtxt('data/explore.csv', names=True, delimiter=',')

# %%
legend_names=[r'$D\tau$', r'$D^*\tau$']

typeset_name = { 
    'ny' : r'$n\Upsilon$',
    'ntracks' : r'$nTracks$',
    'r2' : r'$R2$',
    'r2all' : r'$R2$ All',
    'mmiss2' : r'$M^2_{miss}$',
    'mmiss2prime' : r'adjusted $M^2_{miss}$',
    'eextra' : r'$E_{extra}$',
    'costhetat' : r'$\cos\theta_T$',
    'tag_lp3' : r'$|\vec{p}^{tag}_\ell|$',
    'tag_cosby' : r'$\cos\theta^{tag}_{B\Upsilon}$',
    'tag_costhetadl' : r'$\cos\theta^{tag}_{D\ell}$',
    'tag_dmass' : r'$m^{tag}_{D}$',
    'tag_deltam' : r'$\Delta m^{tag}$',
    'tag_isbdstar' : r'tag $B\rightarrow D^*$?',
    'tag_costhetadsoft' : r'$\cos\theta^{tag}_{Dsoft}$',
    'tag_softp3magcm' : r'$|\vec{p}^{tag}_{soft}|$',
    'sig_hp3' : r'$|\vec{p}^{sig}_{h}|$',
    'sig_cosby' : r'$\cos\theta^{sig}_{B\Upsilon}$',
    'sig_costhetadtau' : r'$\cos\theta^{sig}_{D\tau}$',
    'sig_vtxb' : r'$\chi^2_{sigB}$',
    'sig_isbdstar' : r'sig $B\rightarrow D^*$?',
    'sig_dmass' : r'$m^{sig}_{D}$',
    'sig_deltam' : r'$\Delta m^{sig}$',
    'sig_costhetadsoft' : r'$\cos\theta^{sig}_{Dsoft}$',
    'sig_softp3magcm' : r'$|\vec{p}^{sig}_{soft}|$',
    'sig_hmass' : r'$m^{sig}_h$',
    'sig_vtxh' : r'$\chi^2_{sigh}$',
    'tag_dmode' : r'tag $D$ mode',
    'tag_dstarmode' : r'tag $D^*$ mode',
    'sig_dmode' : r'sig $D$ mode',
    'sig_dstarmode' : r'sig $D^*$ mode',
    'tag_l_epid' : r'tag $\ell$ electron PID',
    'tag_l_mupid' : r'tag $\ell$ muon PID',
    'sig_h_epid' : r'sig $h$ electron PID',
    'sig_h_mupid' : r'sig $h$ muon PID',
    'cand_score' : r'Candidate Score', 
    'signal_score' : r'Signal Score',
}

# %%
def apply_cut(arr, varname, lower=None, upper=None):
    sub_arr = np.copy(arr)
    mask = np.ones(sub_arr.shape[0], dtype=bool)
    if lower is not None: mask &= (sub_arr[varname] >= lower)
    if upper is not None: mask &= (sub_arr[varname] <= upper)
    sub_arr = sub_arr[mask]
    return sub_arr

# %%
y = np.zeros(X.shape[0])
mask = (X['mode_label']==11445) | (X['mode_label'] == 11447)
y[mask] = 1.0
X['eventlabel'] = y

# %%
use_log_yscale = False

# %%
X_cut = apply_cut(X, 'ny', 0, 40)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'ny', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['ny'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'ntracks')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'ntracks', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['ntracks'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'r2')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'r2', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['r2'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'r2all')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'r2all', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['r2all'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'mmiss2', -30, 30)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'mmiss2', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['mmiss2'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'mmiss2prime', -30, 30)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'mmiss2prime', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['mmiss2prime'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'eextra', 0, 4)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'eextra', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['eextra'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'costhetat', -1, 1)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'costhetat', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['costhetat'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_lp3')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_lp3', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['tag_lp3'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_cosby')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_cosby', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['tag_cosby'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_costhetadl')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_costhetadl', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['tag_costhetadl'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_dmass')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_dmass', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['tag_dmass'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_deltam',0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_deltam', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['tag_deltam'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_isbdstar')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_isbdstar', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['tag_isbdstar'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_costhetadsoft', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_costhetadsoft', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['tag_costhetadsoft'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_softp3magcm', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_softp3magcm', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['tag_softp3magcm'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_hp3', 0, 3)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_hp3', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_hp3'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_cosby', -30, 8)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_cosby', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_cosby'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_costhetadtau')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_costhetadtau', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['sig_costhetadtau'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_vtxb')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_vtxb', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_vtxb'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_isbdstar')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_isbdstar', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_isbdstar'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_dmass')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_dmass', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_dmass'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_deltam', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_deltam', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_deltam'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_costhetadsoft', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_costhetadsoft', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['sig_costhetadsoft'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_softp3magcm', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_softp3magcm', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['sig_softp3magcm'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_hmass', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_hmass', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['sig_hmass'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_vtxh', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_vtxh', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=10,
        normed=True,
        xlabel=typeset_name['sig_vtxh'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'cand_score', 0, 0.04)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'cand_score', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['cand_score'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'signal_score', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'signal_score', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['signal_score'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_dmode')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_dmode', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['tag_dmode'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_dstarmode', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_dstarmode', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['tag_dstarmode'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_dmode')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_dmode', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_dmode'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_dstarmode', 0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_dstarmode', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_dstarmode'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_l_epid')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_l_epid', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['tag_l_epid'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'tag_l_mupid')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'tag_l_mupid', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['tag_l_mupid'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_h_epid')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_h_epid', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_h_epid'],
        legend_names=legend_names,
        legend=True)

# %%
X_cut = apply_cut(X, 'sig_h_mupid')

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'sig_h_mupid', Y='eventlabel', weights='weight', ax=ax, 
        stacked=False, show_hist=True, bins=50, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name['sig_h_mupid'],
        legend_names=legend_names,
        legend=True)
