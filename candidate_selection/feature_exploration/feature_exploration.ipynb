# %%
# %matplotlib inline

# %%
import numpy as np
import iopro
import matplotlib.pyplot as plt
from custom_python_utilities.histR import histR, histRec
from matplotlib.backends.backend_pdf import PdfPages

# %%
X = iopro.genfromtxt('data/explore.csv', names=True, delimiter=',')

# %%
legend_names=[r'noise', r'signal']

typeset_name = { 
    'mmiss2' : r'$M^2_{miss}$',
    'mmiss2prime' : r'adjusted $M^2_{miss}$',
    'eextra' : r'$E_{extra}$',
    'costhetat' : r'$\cos\theta_T$',
    'tag_lp3' : r'$|\vec{p}^{tag}_\ell|$',
    'tag_cosby' : r'$\cos\theta^{tag}_{B\Upsilon}$',
    'tag_costhetadl' : r'$\cos\theta^{tag}_{D\ell}$',
    'tag_dmass' : r'$m^{tag}_{D}$',
    'tag_deltam' : r'$\Delta m^{tag}$',
    'tag_isbdstar' : r'tag $B\rightarrow D^*$?',
    'tag_costhetadsoft' : r'$\cos\theta^{tag}_{Dsoft}$',
    'tag_softp3magcm' : r'$|\vec{p}^{tag}_{soft}|$',
    'sig_hp3' : r'$|\vec{p}^{sig}_{h}|$',
    'sig_cosby' : r'$\cos\theta^{sig}_{B\Upsilon}$',
    'sig_costhetadtau' : r'$\cos\theta^{sig}_{D\tau}$',
    'sig_vtxb' : r'$\chi^2_{sigB}$',
    'sig_isbdstar' : r'sig $B\rightarrow D^*$?',
    'sig_dmass' : r'$m^{sig}_{D}$',
    'sig_deltam' : r'$\Delta m^{sig}$',
    'sig_costhetadsoft' : r'$\cos\theta^{sig}_{Dsoft}$',
    'sig_softp3magcm' : r'$|\vec{p}^{sig}_{soft}|$',
    'sig_hmass' : r'$m^{sig}_h$',
    'sig_vtxh' : r'$\chi^2_{sigh}$',
    'tag_dmode' : r'tag $D$ mode',
    'tag_dstarmode' : r'tag $D^*$ mode',
    'sig_dmode' : r'sig $D$ mode',
    'sig_dstarmode' : r'sig $D^*$ mode',
    'tag_l_epid' : r'tag $\ell$ electron PID',
    'tag_l_mupid' : r'tag $\ell$ muon PID',
    'sig_h_epid' : r'sig $h$ electron PID',
    'sig_h_mupid' : r'sig $h$ muon PID', 
    'cand_score' : r'Candidate Score'
}

# %%
def apply_cut(arr, varname, lower=None, upper=None):
    sub_arr = np.copy(arr)
    mask = np.ones(sub_arr.shape[0], dtype=bool)
    if lower is not None: mask &= (sub_arr[varname] >= lower)
    if upper is not None: mask &= (sub_arr[varname] <= upper)
    sub_arr = sub_arr[mask]
    return sub_arr

# %%
use_log_yscale = False
save_pdf = True
pdf = None

if save_pdf: 
    pdf = PdfPages('candidate_selection_plots.pdf')

# %%
X_cut = apply_cut(X, 'cand_score', 0, 0.7)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'cand_score', Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=100, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['cand_score'],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
X_cut = apply_cut(X, 'mmiss2', -20, 40)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'mmiss2', Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=50, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['mmiss2'],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
X_cut = apply_cut(X, 'mmiss2prime',-20,20)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'mmiss2prime', Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=60, 
        show_spline=True, knots_spline=50,
        normed=True,
        xlabel=typeset_name['mmiss2prime'],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
X_cut = apply_cut(X, 'eextra',-1, 3)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, 'eextra', Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name['eextra'],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'costhetat'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_lp3'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_cosby'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_costhetadl'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_dmass'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_deltam'
X_cut = apply_cut(X, varname, 0.1)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_isbdstar'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=40, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_costhetadsoft'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_softp3magcm'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_hp3'
X_cut = apply_cut(X, varname, 0, 2)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_cosby'
X_cut = apply_cut(X, varname, -40, 5)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_costhetadtau'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_vtxb'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_isbdstar'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=40, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_dmass'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_deltam'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_costhetadsoft'
X_cut = apply_cut(X, varname, -100)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_softp3magcm'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_hmass'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_vtxh'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=False, bins=40, 
        show_spline=True, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_dmode'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=100, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_dstarmode'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=100, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_dmode'
X_cut = apply_cut(X, varname)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=100, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_dstarmode'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=100, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_l_epid'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=100, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'tag_l_mupid'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=100, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_h_epid'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=100, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
varname = 'sig_h_mupid'
X_cut = apply_cut(X, varname, 0.0)

fig = plt.figure(figsize=(6*1.618, 6))
ax = fig.add_subplot(111)
if use_log_yscale: ax.set_yscale('log')
ax.tick_params(axis='both', which='major', labelsize=16)

histRec(X_cut, varname, Y='is_matched', ax=ax, 
        stacked=False, show_hist=True, bins=100, 
        show_spline=False, knots_spline=20,
        normed=True,
        xlabel=typeset_name[varname],
        legend_names=legend_names,
        legend=True)

if save_pdf: pdf.savefig()

# %%
if save_pdf: pdf.close()
